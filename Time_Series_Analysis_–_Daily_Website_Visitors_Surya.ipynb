# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import pandas as pd

df = pd.read_csv("/content/drive/MyDrive/dataset/daily-website-visitors.csv")
df.describe()
# Out:
#                Row  Day.Of.Week
# count  2167.000000  2167.000000
# mean   1084.000000     3.997231
# std     625.703338     2.000229
# min       1.000000     1.000000
# 25%     542.500000     2.000000
# 50%    1084.000000     4.000000
# 75%    1625.500000     6.000000
# max    2167.000000     7.000000

# %%
df
# Out:
#        Row        Day  Day.Of.Week       Date Page.Loads Unique.Visits  \
# 0        1     Sunday            1  9/14/2014      2,146         1,582
# 1        2     Monday            2  9/15/2014      3,621         2,528
# 2        3    Tuesday            3  9/16/2014      3,698         2,630
# 3        4  Wednesday            4  9/17/2014      3,667         2,614
# 4        5   Thursday            5  9/18/2014      3,316         2,366
# ...    ...        ...          ...        ...        ...           ...
# 2162  2163   Saturday            7  8/15/2020      2,221         1,696
# 2163  2164     Sunday            1  8/16/2020      2,724         2,037
# 2164  2165     Monday            2  8/17/2020      3,456         2,638
# 2165  2166    Tuesday            3  8/18/2020      3,581         2,683
# 2166  2167  Wednesday            4  8/19/2020      2,064         1,564
#
#      First.Time.Visits Returning.Visits
# 0                1,430              152
# ...

# %%
df = df.drop(["Row","Day.Of.Week"],axis = 1)
df
# Out:
#             Day       Date Page.Loads Unique.Visits First.Time.Visits  \
# 0        Sunday  9/14/2014      2,146         1,582             1,430
# 1        Monday  9/15/2014      3,621         2,528             2,297
# 2       Tuesday  9/16/2014      3,698         2,630             2,352
# 3     Wednesday  9/17/2014      3,667         2,614             2,327
# 4      Thursday  9/18/2014      3,316         2,366             2,130
# ...         ...        ...        ...           ...               ...
# 2162   Saturday  8/15/2020      2,221         1,696             1,373
# 2163     Sunday  8/16/2020      2,724         2,037             1,686
# 2164     Monday  8/17/2020      3,456         2,638             2,181
# 2165    Tuesday  8/18/2020      3,581         2,683             2,184
# 2166  Wednesday  8/19/2020      2,064         1,564             1,297
#
#      Returning.Visits
# 0                 152
# 1                 231
# 2                 278
# 3                 287
# ...

# %%
df.dropna()
# Out:
#             Day       Date Page.Loads Unique.Visits First.Time.Visits  \
# 0        Sunday  9/14/2014      2,146         1,582             1,430
# 1        Monday  9/15/2014      3,621         2,528             2,297
# 2       Tuesday  9/16/2014      3,698         2,630             2,352
# 3     Wednesday  9/17/2014      3,667         2,614             2,327
# 4      Thursday  9/18/2014      3,316         2,366             2,130
# ...         ...        ...        ...           ...               ...
# 2162   Saturday  8/15/2020      2,221         1,696             1,373
# 2163     Sunday  8/16/2020      2,724         2,037             1,686
# 2164     Monday  8/17/2020      3,456         2,638             2,181
# 2165    Tuesday  8/18/2020      3,581         2,683             2,184
# 2166  Wednesday  8/19/2020      2,064         1,564             1,297
#
#      Returning.Visits
# 0                 152
# 1                 231
# 2                 278
# 3                 287
# ...

# %%
df
# Out:
#             Day       Date Page.Loads Unique.Visits First.Time.Visits  \
# 0        Sunday  9/14/2014      2,146         1,582             1,430
# 1        Monday  9/15/2014      3,621         2,528             2,297
# 2       Tuesday  9/16/2014      3,698         2,630             2,352
# 3     Wednesday  9/17/2014      3,667         2,614             2,327
# 4      Thursday  9/18/2014      3,316         2,366             2,130
# ...         ...        ...        ...           ...               ...
# 2162   Saturday  8/15/2020      2,221         1,696             1,373
# 2163     Sunday  8/16/2020      2,724         2,037             1,686
# 2164     Monday  8/17/2020      3,456         2,638             2,181
# 2165    Tuesday  8/18/2020      3,581         2,683             2,184
# 2166  Wednesday  8/19/2020      2,064         1,564             1,297
#
#      Returning.Visits
# 0                 152
# 1                 231
# 2                 278
# 3                 287
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2167 entries, 0 to 2166
# Data columns (total 6 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Day                2167 non-null   object
#  1   Date               2167 non-null   object
#  2   Page.Loads         2167 non-null   object
#  3   Unique.Visits      2167 non-null   object
#  4   First.Time.Visits  2167 non-null   object
#  5   Returning.Visits   2167 non-null   object
# dtypes: object(6)
# memory usage: 101.7+ KB

# %%
df['Date'] = pd.to_datetime(df['Date'])
df['Page.Loads'] = df['Page.Loads'].str.replace(',','').astype(int)
df['Unique.Visits'] = df['Unique.Visits'].str.replace(',','').astype(int)
df['First.Time.Visits'] = df['First.Time.Visits'].str.replace(',','').astype(int)
df['Returning.Visits'] = df['Returning.Visits'].str.replace(',','').astype(int)

# %%
df
# Out:
#             Day       Date  Page.Loads  Unique.Visits  First.Time.Visits  \
# 0        Sunday 2014-09-14        2146           1582               1430
# 1        Monday 2014-09-15        3621           2528               2297
# 2       Tuesday 2014-09-16        3698           2630               2352
# 3     Wednesday 2014-09-17        3667           2614               2327
# 4      Thursday 2014-09-18        3316           2366               2130
# ...         ...        ...         ...            ...                ...
# 2162   Saturday 2020-08-15        2221           1696               1373
# 2163     Sunday 2020-08-16        2724           2037               1686
# 2164     Monday 2020-08-17        3456           2638               2181
# 2165    Tuesday 2020-08-18        3581           2683               2184
# 2166  Wednesday 2020-08-19        2064           1564               1297
#
#       Returning.Visits
# 0                  152
# 1                  231
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2167 entries, 0 to 2166
# Data columns (total 6 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Day                2167 non-null   object
#  1   Date               2167 non-null   datetime64[ns]
#  2   Page.Loads         2167 non-null   int64
#  3   Unique.Visits      2167 non-null   int64
#  4   First.Time.Visits  2167 non-null   int64
#  5   Returning.Visits   2167 non-null   int64
# dtypes: datetime64[ns](1), int64(4), object(1)
# memory usage: 101.7+ KB

# %%
df['Day'].value_counts()
# Out:
# Sunday       310
# Monday       310
# Tuesday      310
# Wednesday    310
# Thursday     309
# Friday       309
# Saturday     309
# Name: Day, dtype: int64

# %%
df.index
# Out:
# RangeIndex(start=0, stop=2167, step=1)

# %%
import matplotlib.pyplot as plt
# Feching years
year = df['Date'].dt.year
# Visualizing the time series by plotting number of passengers versus time
fig, ax = plt.subplots()
ax.plot(df['Page.Loads'])
ax.set_title('Number of Page.Loads', weight='bold', fontsize=18) # Title
ax.set_ylabel('Number of Page.Loads', fontsize=15)
ax.set_xlabel('Year: Jan 2015 to Dec 2020', fontsize=15)
ax.set_xticklabels(np.unique(year))
fig.show()

# %%
import matplotlib.pyplot as plt
# Feching years
year = df['Date'].dt.year
# Visualizing the time series by plotting number of passengers versus time
fig, ax = plt.subplots()
ax.plot(df['Unique.Visits'])
ax.set_title('Number of Unique.Visits', weight='bold', fontsize=18) # Title
ax.set_ylabel('Number of Unique.Visits', fontsize=15)
ax.set_xlabel('Year: Jan 2015 to Dec 2020', fontsize=15)
ax.set_xticklabels(np.unique(year))
fig.show()

# %%
import matplotlib.pyplot as plt
# Feching years
year = df['Date'].dt.year
# Visualizing the time series by plotting number of passengers versus time
fig, ax = plt.subplots()
ax.plot(df['Day'])
ax.set_title('Number of Day', weight='bold', fontsize=18) # Title
ax.set_ylabel('Number of Day', fontsize=15)
ax.set_xlabel('Year: Jan 2015 to Dec 2020', fontsize=15)
ax.set_xticklabels(np.unique(year))
fig.show()

# %%
import matplotlib.pyplot as plt
# Feching years
year = df['Date'].dt.year
# Visualizing the time series by plotting number of passengers versus time
fig, ax = plt.subplots()
ax.plot(df['First.Time.Visits'])
ax.set_title('Number of First.Time.Visits', weight='bold', fontsize=18) # Title
ax.set_ylabel('Number of First.Time.Visits', fontsize=15)
ax.set_xlabel('Year: Jan 2015 to Dec 2020', fontsize=15)
ax.set_xticklabels(np.unique(year))
fig.show()

# %%
import matplotlib.pyplot as plt
# Feching years
year = df['Date'].dt.year
# Visualizing the time series by plotting number of passengers versus time
fig, ax = plt.subplots()
ax.plot(df['Returning.Visits'])
ax.set_title('Number of Returning.Visits', weight='bold', fontsize=18) # Title
ax.set_ylabel('Number of Returning.Visits', fontsize=15)
ax.set_xlabel('Year: Jan 2015 to Dec 2020', fontsize=15)
ax.set_xticklabels(np.unique(year))
fig.show()

# %%
# Comparing minimum and maximum price of car
plt.plot(df["Day"], label='Day')
plt.plot(df["Page.Loads"], label='Page.Loads')
plt.plot(df["Unique.Visits"], label='Unique.Visits')
plt.plot(df["First.Time.Visits"], label='First.Time.Visits')
plt.plot(df["Returning.Visits"], label='Returning.Visits')
plt.legend()
plt.xlabel('Years', fontsize=15)
plt.ylabel('Features', fontsize=15)
plt.title('Features', weight='bold', fontsize=18)
plt.show()

# %%
df.index = df['Date'] #date as index
df
# Out:
#                   Day       Date  Page.Loads  Unique.Visits  \
# Date
# 2014-09-14     Sunday 2014-09-14        2146           1582
# 2014-09-15     Monday 2014-09-15        3621           2528
# 2014-09-16    Tuesday 2014-09-16        3698           2630
# 2014-09-17  Wednesday 2014-09-17        3667           2614
# 2014-09-18   Thursday 2014-09-18        3316           2366
# ...               ...        ...         ...            ...
# 2020-08-15   Saturday 2020-08-15        2221           1696
# 2020-08-16     Sunday 2020-08-16        2724           2037
# 2020-08-17     Monday 2020-08-17        3456           2638
# 2020-08-18    Tuesday 2020-08-18        3581           2683
# 2020-08-19  Wednesday 2020-08-19        2064           1564
#
#             First.Time.Visits  Returning.Visits
# Date
# 2014-09-14               1430               152
# 2014-09-15               2297               231
# 2014-09-16               2352               278
# ...

# %%
#drop date column
df.drop(['Date'],axis = 1, inplace = True)
df
# Out:
#                   Day  Page.Loads  Unique.Visits  First.Time.Visits  \
# Date
# 2014-09-14     Sunday        2146           1582               1430
# 2014-09-15     Monday        3621           2528               2297
# 2014-09-16    Tuesday        3698           2630               2352
# 2014-09-17  Wednesday        3667           2614               2327
# 2014-09-18   Thursday        3316           2366               2130
# ...               ...         ...            ...                ...
# 2020-08-15   Saturday        2221           1696               1373
# 2020-08-16     Sunday        2724           2037               1686
# 2020-08-17     Monday        3456           2638               2181
# 2020-08-18    Tuesday        3581           2683               2184
# 2020-08-19  Wednesday        2064           1564               1297
#
#             Returning.Visits
# Date
# 2014-09-14               152
# 2014-09-15               231
# 2014-09-16               278
# ...

# %%
# Now we need to change the frequency from daily to monthly
# M => is for month
df.resample('M').mean().head()# head => first 5

# # A => is for year
# df.resample('A').mean().head()# head => first 5

# # Q => is for quaterly
# df.resample('Q').mean().head()# head => first 5
# Out:
#              Page.Loads  Unique.Visits  First.Time.Visits  Returning.Visits
# Date
# 2014-09-30  3297.176471    2326.117647        2090.705882        235.411765
# 2014-10-31  3934.935484    2760.290323        2436.645161        323.645161
# 2014-11-30  3806.333333    2717.100000        2353.033333        364.066667
# 2014-12-31  3407.000000    2451.774194        2086.354839        365.419355
# 2015-01-31  3099.258065    2156.870968        1839.032258        317.838710

# %%
# Importing necessary libraries
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings("ignore")
# In case if you are working in a notebook
# %matplotlib inline
df.describe().T
# Out:
#                     count         mean          std     min     25%     50%  \
# Page.Loads         2167.0  4116.989386  1350.977843  1002.0  3114.5  4106.0
# Unique.Visits      2167.0  2943.646516   977.886472   667.0  2226.0  2914.0
# First.Time.Visits  2167.0  2431.824181   828.704688   522.0  1830.0  2400.0
# Returning.Visits   2167.0   511.822335   168.736370   133.0   388.5   509.0
#
#                       75%     max
# Page.Loads         5020.5  7984.0
# Unique.Visits      3667.5  5541.0
# First.Time.Visits  3038.0  4616.0
# Returning.Visits    626.5  1036.0
